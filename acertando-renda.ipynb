# %%
import nltk
import numpy as np
import random
import string

import bs4 as bs
import urllib.request
import re

import pandas, numpy
import pandas as pd 
import numpy as np

from nltk.corpus import webtext 
from nltk.collocations import BigramCollocationFinder 
from nltk.metrics import BigramAssocMeasures 
from random import random
from collections           import defaultdict
from gensim.models.phrases import Phrases, Phraser

from pandas import read_csv
from matplotlib import pyplot
import matplotlib.pyplot as plt

# %%
df2 = pd.read_csv('C:/AI/alphavox/Bradesco7/renda.csv', encoding='latin-1')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df3 = pd.DataFrame(columns=['cep','A','B','C','D','E'])

# %%
count2=1000
for i in range(len(df2)):
    count=0
    
    if i==count2:
        print(count,count2,i)
        count2=count2+1000
        count=count+1
    tcep=df2['cep'][i]
    trenda=df2['renda'][i]
    tquant=df2['quant'][i]
    achei = 0
    for i1 in range(len(df3)):
        if tcep==df3['cep'][i1]:
            achei=1
            if trenda=="A":
                df3['A'][i1]=df3['A'][i1]+tquant
            if trenda=="B":
                df3['B'][i1]=df3['B'][i1]+tquant
            if trenda=="C":
                df3['C'][i1]=df3['C'][i1]+tquant
            if trenda=="D":
                df3['D'][i1]=df3['D'][i1]+tquant
            if trenda=="E":
                df3['E'][i1]=df3['E'][i1]+tquant
            break
    if achei==0:
        trendaA=0
        trendaB=0
        trendaC=0
        trendaD=0
        trendaD=0
        if trenda=="A":
            trendaA=tquant
        if trenda=="B":
            trendaB=tquant
        if trenda=="C":
            trendaC=tquant
        if trenda=="D":
            trendaD=tquant
        if trenda=="E":
            trendaE=tquant
       
        df3 = df3.append({'cep':tcep,'A':trendaA,'B':trendaB,'C':trendaC,'D':trendaD,'E':trendaE}, ignore_index=True)  
        df3 = df3.reindex()
# Out:
# 0 1000 1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-0e48879645dd> in <module>
#      42             trendaE=tquant
#      43
# ---> 44         df3 = df3.append({'cep':tcep,'A':trendaA,'B':trendaB,'C':trendaC,'D':trendaD,'E':trendaE}, ignore_index=True)
#      45         df3 = df3.reindex()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7058                 combined_columns = self.columns.astype(object).append(idx_diff)
#    7059             other = (
# -> 7060                 other.reindex(combined_columns, copy=False)
#    7061                 .to_frame()
#    7062                 .T.infer_objects()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in transpose(self, copy, *args)
#    2710                 new_values = new_values.copy()
# ...

# %%
df3
# Out:
#            cep  A  B  C  D    E
# 0     57300380  0  0  0  0   10
# 1     79820019  0  0  0  0    4
# 2     15741289  0  0  0  0    5
# 3     54590000  0  0  0  0  184
# 4     12287360  0  0  0  0    6
# ...        ... .. .. .. ..  ...
# 1319  63280000  0  0  0  0  212
# 1320  19901530  0  0  0  0    1
# 1321  20771595  0  0  0  0    1
# 1322  17801929  0  0  0  0    2
# 1323  63140000  0  0  0  0  562
#
# [1324 rows x 6 columns]

# %%
df3.to_csv('C:/AI/alphavox/Bradesco7/renda-y.csv')
